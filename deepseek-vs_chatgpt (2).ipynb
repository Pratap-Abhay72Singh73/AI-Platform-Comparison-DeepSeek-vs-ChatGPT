# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\abhay\anaconda3\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
df = pd.read_csv("deepseek_vs_chatgpt.csv")
df.head()
# Out:
#          Date  Month_Num   Weekday AI_Platform   AI_Model_Version  \
# 0  2024-09-21          9  Saturday     ChatGPT        GPT-4-turbo
# 1  2024-09-21          9  Saturday     ChatGPT        GPT-4-turbo
# 2  2024-09-21          9  Saturday     ChatGPT        GPT-4-turbo
# 3  2024-09-21          9  Saturday     ChatGPT        GPT-4-turbo
# 4  2024-05-16          5  Thursday    DeepSeek  DeepSeek-Chat 1.5
#
#    Active_Users  New_Users  Churned_Users  Daily_Churn_Rate  Retention_Rate  \
# 0        500000      25000          25000              0.05            0.95
# 1        500000      25000          25000              0.05            0.95
# 2        500000      25000          25000              0.05            0.95
# 3        500000      25000          25000              0.05            0.95
# 4       1700000     170000          34000              0.02            0.95
#
#    ... Session_Duration_sec     Device_Type Language  Response_Accuracy  \
# 0  ...                   40          Mobile       es             0.7842
# 1  ...                   24  Laptop/Desktop       zh             0.8194
# 2  ...                   34          Mobile       en             0.8090
# 3  ...                   18          Mobile       fr             0.8233
# 4  ...                   10          Mobile       de             0.9366
#
#    Response_Speed_sec Response_Time_Category  Correction_Needed  \
# 0                3.30               Standard                  0
# 1                3.28               Standard                  1
# 2                3.07               Standard                  0
# 3                3.06               Standard                  0
# 4                1.48                   Fast                  0
#
#    User_Return_Frequency  Customer_Support_Interactions  \
# 0                      6                              2
# 1                      2                              2
# 2                      2                              0
# 3                      9                              0
# 4                      9                              3
#
#                                          Region
# 0  Antarctica (the territory South of 60 deg S)
# 1                                       Ukraine
# 2                                       Grenada
# 3                                        Guyana
# 4                                         India
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (10000, 28)

# %% [markdown]
# ### Data Cleaning

# %%
df.isnull().sum()
# Out:
# Date                               0
# Month_Num                          0
# Weekday                            0
# AI_Platform                        0
# AI_Model_Version                   0
# Active_Users                       0
# New_Users                          0
# Churned_Users                      0
# Daily_Churn_Rate                   0
# Retention_Rate                     0
# User_ID                            0
# Query_Type                         0
# Input_Text                         0
# Input_Text_Length                  0
# Response_Tokens                    0
# Topic_Category                     0
# User_Rating                        0
# User_Experience_Score              0
# Session_Duration_sec               0
# Device_Type                        0
# Language                           0
# Response_Accuracy                379
# Response_Speed_sec                 0
# Response_Time_Category             0
# Correction_Needed                  0
# User_Return_Frequency              0
# Customer_Support_Interactions      0
# Region                             0
# dtype: int64

# %%
df[df['Response_Accuracy'].isnull()==True]
# Out:
#             Date  Month_Num    Weekday AI_Platform   AI_Model_Version  \
# 62    2023-08-12          8   Saturday     ChatGPT        GPT-4-turbo
# 86    2024-06-04          6    Tuesday     ChatGPT        GPT-4-turbo
# 105   2024-11-06         11  Wednesday     ChatGPT        GPT-4-turbo
# 162   2024-12-28         12   Saturday     ChatGPT        GPT-4-turbo
# 167   2024-04-19          4     Friday    DeepSeek  DeepSeek-Chat 1.5
# ...          ...        ...        ...         ...                ...
# 9893  2024-10-01         10    Tuesday     ChatGPT        GPT-4-turbo
# 9900  2024-05-30          5   Thursday    DeepSeek  DeepSeek-Chat 1.5
# 9923  2023-11-27         11     Monday     ChatGPT        GPT-4-turbo
# 9971  2024-06-25          6    Tuesday     ChatGPT        GPT-4-turbo
# 9981  2023-11-01         11  Wednesday     ChatGPT        GPT-4-turbo
#
#       Active_Users  New_Users  Churned_Users  Daily_Churn_Rate  \
# 62         1150000      57500          57500              0.05
# 86          650000      32500          32500              0.05
# 105         400000      20000          20000              0.05
# 162         350000      17500          17500              0.05
# 167        1550000     155000          31000              0.02
# ...            ...        ...            ...               ...
# 9893        450000      22500          22500              0.05
# 9900       1700000     170000          34000              0.02
# 9923       1000000      50000          50000              0.05
# 9971        650000      32500          32500              0.05
# 9981       1000000      50000          50000              0.05
#
#       Retention_Rate  ... Session_Duration_sec     Device_Type Language  \
# 62              0.95  ...                   16  Laptop/Desktop       de
# 86              0.95  ...                    8  Laptop/Desktop       es
# 105             0.95  ...                   14  Laptop/Desktop       en
# 162             0.95  ...                   38          Mobile       es
# 167             0.95  ...                   31          Mobile       zh
# ...              ...  ...                  ...             ...      ...
# 9893            0.95  ...                   21  Laptop/Desktop       en
# 9900            0.95  ...                   10  Laptop/Desktop       de
# 9923            0.95  ...                   37          Mobile       es
# 9971            0.95  ...                   18  Laptop/Desktop       es
# 9981            0.95  ...                   12  Laptop/Desktop       en
#
#       Response_Accuracy  Response_Speed_sec Response_Time_Category  \
# 62                  NaN                2.91                   Fast
# 86                  NaN                3.28               Standard
# 105                 NaN                3.95               Standard
# 162                 NaN                3.80               Standard
# 167                 NaN                1.09                   Fast
# ...                 ...                 ...                    ...
# 9893                NaN                1.90                   Fast
# 9900                NaN                1.48                   Fast
# 9923                NaN                4.84               Standard
# 9971                NaN                3.63               Standard
# 9981                NaN                3.49               Standard
#
#       Correction_Needed  User_Return_Frequency  Customer_Support_Interactions  \
# 62                    0                      7                              3
# 86                    1                      9                              3
# 105                   1                      8                              0
# 162                   0                      8                              0
# 167                   0                      3                              3
# ...                 ...                    ...                            ...
# 9893                  0                      3                              1
# 9900                  0                      5                              2
# 9923                  0                      2                              1
# 9971                  0                      9                              1
# 9981                  0                      8                              2
#
#               Region
# 62           Moldova
# 86          Maldives
# 105   Western Sahara
# 162            Benin
# 167            Japan
# ...              ...
# 9893           Qatar
# 9900        Botswana
# 9923  Czech Republic
# 9971         Tunisia
# 9981  Czech Republic
#
# [379 rows x 28 columns]

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (9621, 28)

# %%
df.columns
# Out:
# Index(['Date', 'Month_Num', 'Weekday', 'AI_Platform', 'AI_Model_Version',
#        'Active_Users', 'New_Users', 'Churned_Users', 'Daily_Churn_Rate',
#        'Retention_Rate', 'User_ID', 'Query_Type', 'Input_Text',
#        'Input_Text_Length', 'Response_Tokens', 'Topic_Category', 'User_Rating',
#        'User_Experience_Score', 'Session_Duration_sec', 'Device_Type',
#        'Language', 'Response_Accuracy', 'Response_Speed_sec',
#        'Response_Time_Category', 'Correction_Needed', 'User_Return_Frequency',
#        'Customer_Support_Interactions', 'Region'],
#       dtype='object')

# %% [markdown]
# ### Connecting to MySQL

# %%
engine = create_engine("mysql+pymysql://student:@localhost:3306/ai_comparison_db")
df.to_sql("deepseek_vs_chatgpt",con=engine,index=False,if_exists='replace')
# Out:
# 9621

# %%
df=pd.read_sql("select * from deepseek_vs_chatgpt",con=engine)
print(df)
# Out:
#             Date  Month_Num   Weekday AI_Platform   AI_Model_Version  \
# 0     2024-09-21          9  Saturday     ChatGPT        GPT-4-turbo
# 1     2024-09-21          9  Saturday     ChatGPT        GPT-4-turbo
# 2     2024-09-21          9  Saturday     ChatGPT        GPT-4-turbo
# 3     2024-09-21          9  Saturday     ChatGPT        GPT-4-turbo
# 4     2024-05-16          5  Thursday    DeepSeek  DeepSeek-Chat 1.5
# ...          ...        ...       ...         ...                ...
# 9616  2024-05-17          5    Friday    DeepSeek  DeepSeek-Chat 1.5
# 9617  2024-05-17          5    Friday    DeepSeek  DeepSeek-Chat 1.5
# 9618  2024-05-17          5    Friday    DeepSeek  DeepSeek-Chat 1.5
# 9619  2024-05-17          5    Friday    DeepSeek  DeepSeek-Chat 1.5
# 9620  2024-05-17          5    Friday    DeepSeek  DeepSeek-Chat 1.5
#
#       Active_Users  New_Users  Churned_Users  Daily_Churn_Rate  \
# 0           500000      25000          25000              0.05
# 1           500000      25000          25000              0.05
# 2           500000      25000          25000              0.05
# 3           500000      25000          25000              0.05
# 4          1700000     170000          34000              0.02
# ...            ...        ...            ...               ...
# 9616       1700000     170000          34000              0.02
# 9617       1700000     170000          34000              0.02
# 9618       1700000     170000          34000              0.02
# 9619       1700000     170000          34000              0.02
# 9620       1700000     170000          34000              0.02
#
#       Retention_Rate  ... Session_Duration_sec     Device_Type Language  \
# 0               0.95  ...                   40          Mobile       es
# 1               0.95  ...                   24  Laptop/Desktop       zh
# 2               0.95  ...                   34          Mobile       en
# 3               0.95  ...                   18          Mobile       fr
# 4               0.95  ...                   10          Mobile       de
# ...              ...  ...                  ...             ...      ...
# 9616            0.95  ...                   34  Laptop/Desktop       zh
# 9617            0.95  ...                   19  Laptop/Desktop       en
# 9618            0.95  ...                   29  Laptop/Desktop       de
# 9619            0.95  ...                   21          Mobile       de
# 9620            0.95  ...                   58          Mobile       fr
#
#       Response_Accuracy  Response_Speed_sec Response_Time_Category  \
# 0                0.7842                3.30               Standard
# 1                0.8194                3.28               Standard
# 2                0.8090                3.07               Standard
# 3                0.8233                3.06               Standard
# 4                0.9366                1.48                   Fast
# ...                 ...                 ...                    ...
# 9616             0.9791                0.60                Instant
# 9617             0.9132                0.83                Instant
# 9618             0.9516                0.94                Instant
# 9619             0.9359                0.83                Instant
# 9620             0.9399                0.76                Instant
#
#       Correction_Needed  User_Return_Frequency  Customer_Support_Interactions  \
# 0                     0                      6                              2
# 1                     1                      2                              2
# 2                     0                      2                              0
# 3                     0                      9                              0
# 4                     0                      9                              3
# ...                 ...                    ...                            ...
# 9616                  0                      7                              2
# 9617                  0                      5                              0
# 9618                  0                     10                              2
# 9619                  0                      5                              3
# 9620                  1                      7                              1
#
#                                             Region
# 0     Antarctica (the territory South of 60 deg S)
# 1                                          Ukraine
# 2                                          Grenada
# 3                                           Guyana
# 4                                            India
# ...                                            ...
# 9616                                    Seychelles
# 9617                              Christmas Island
# 9618                                      Ethiopia
# 9619                                   Puerto Rico
# 9620                               Kyrgyz Republic
#
# [9621 rows x 28 columns]
